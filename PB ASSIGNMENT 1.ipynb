# %% [markdown]
# 1. What are the differences between operators and values in the following? *
# 'hello'
# -87.8
# -/
# +
# 6
# 2. What is the difference between string and variable?
# spam
# 'spam'
# 3. Describe three different data forms.
# 4. What makes up an expression? What are the functions of all expressions?
# 5. In this chapter, assignment statements such as spam = 10 were added. What's the
# difference between a declaration and an expression?
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
# 8. Why is it that eggs is a true variable name but 100 is not?
# 9. Which of the following three functions may be used to convert a value to an integer, a
# floating-point number, or a string?
# 10. What is the error caused by this expression? What would you do about it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# #ANSWER 1
#
# What are the differences between operators and values in the following? *
#
# - 'hello' --> string
# - -87.8 --> float
# - -  --> Subtraction
# - /   -->division
# - +   ---> Addition
# - 6   ---> Integer

# %% [markdown]
# ANSWER 2
#
# What is the difference between string and variable?
# - A string is a data type that is array/list of characters. 'spam'
# - Variable is the name points to a memory location that stores data which can be accessed easily by variable name. spam=datatype

# %% [markdown]
# ANSWER3
#
# Describe three different data forms.
# - number
# - String
# - Tuple
# - Dictionary

# %% [markdown]
# ANSWER 4
#
# What makes up an expression? What are the functions of all expressions?
#
# - An expression can be made up of
# - String (characters only)
# - Alphla numeric (numbers and charcters)
# - only numbers
#
# - functions of an expression can be away to represen data

# %% [markdown]
# ANSWER 5
#
# - In this chapter, assignment statements such as spam = 10 were added. What's the difference between a declaration and an expression?
# - Declaration is to the declare a variable or a function. To define the contents of the function or a varible
# - Expression is a type of a data that is stored in a varible.

# %% [markdown]
# ANSWER 6
# - After running the following code, what does the variable bacon contain? bacon = 22 bacon + 1
# - following code will give Type error as syntax is not correct

# %% [markdown]
# ANSWER 7
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam' --> spamspamspam
#
# 'spam' * 3 -->spamspamspam

# %%
print('spam' * 3)
print('spam' + 'spamspam')
# Out:
# spamspamspam
# spamspamspam

# %% [markdown]
# ANSWER 8
#
# - Why is it that eggs is a true variable name but 100 is not?
#
# - Because a variable name can only start with a alphabet not with any special charter or integer

# %%
@v=23
# Out:
#   File "<ipython-input-15-eb319c5a8758>", line 1
#     @v=23
#       ^
# SyntaxError: invalid syntax

# %%
v='vaibhav'
v
# Out:
# 'vaibhav'

# %%
12aa=c
# Out:
#   File "<ipython-input-17-5c52d556e948>", line 1
#     12aa=c
#       ^
# SyntaxError: invalid syntax

# %%
100=vai
# Out:
#   File "<ipython-input-18-85a936eeaa0c>", line 1
#     100=vai
#     ^
# SyntaxError: cannot assign to literal

# %% [markdown]
# ANSWER 9
#
# Which of the following three functions may be used to convert a value to an integer, a floating-point number, or a string?
#
# - int()
# - float()
# - str()

# %% [markdown]
# ANSWER 10
#
# - What is the error caused by this expression? What would you do about it? 'I have eaten ' + 99 + ' burritos.'
#
# - Type ERROR. As 99 is a int format and to concatenate all the three expressions 99 is to be converted to string

# %%
'I have eaten ' + 99 + ' burritos.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-d24137131a5c> in <module>
# ----> 1 'I have eaten ' + 99 + ' burritos.'
#
# TypeError: can only concatenate str (not "int") to str

# %%
'I have eaten ' + str(99) + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
